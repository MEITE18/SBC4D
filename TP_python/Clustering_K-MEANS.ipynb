# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset= pd.read_csv("D:\TP DEH ABOUBACAR\STAGE_SEJEN\MACHINE LEARNING\shopping.csv")
print(dataset)
x=dataset.iloc[:, [3,4]].values
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Méthode de Elbow
from sklearn.cluster import KMeans
ssd = [ ]
for i in range(1,11):
    kmeansObj = KMeans(n_clusters=i)
    kmeansObj.fit(x)
    ssd.append(kmeansObj.inertia_)
plt.plot(range(1,11),ssd)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Within Cluster Variability')
plt.show()

# %%
#Ajustement K-means
kmeansObj = KMeans(n_clusters=5)
y_kmeans = kmeansObj.fit_predict(x)

# Visualisation des clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'High Income Low Spending')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Medium Income Medium Spending')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'purple', label = 'High Income High Spending')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Low Income Low Spending')
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Low Income HighSpending')
plt.scatter(kmeansObj.cluster_centers_[:, 0], kmeansObj.cluster_centers_[:, 1], s = 300, c = 'yellow', label ='Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.2))
plt.show()

# %%
#Clustering Hiérarchique  #Importation deslibrairies
import numpy as np import matplotlib.pyplot asplt  import pandas aspd
#Chargement de la donnéeavecpandas  
dataset =pd.read_csv('"D:\TP DEH ABOUBACAR\STAGE_SEJEN\MACHINE LEARNING\shopping.csv"') 
x = dataset.iloc[:,[3,4]].values

# %%
#Trouver le nombre optimal de cluster en utilisant le dendrogramme  
import scipy.cluster.hierarchy as sch 
dendro = sch.dendrogram(sch.linkage(x,method='ward')) 
plt.title('Dendrogram') 
plt.xlabel('Customers')  
plt.ylabel('Eucliden Distances')  
plt.show()
#Clustering hiérarchique sur notredonnée
from sklearn.cluster import AgglomerativeClustering 
aggloClusObj =  AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='ward')  
y_result =aggloClusObj.fit_predict(x)

# %%
# Visualisation desclusters
plt.scatter(x[y_result== 0, 0], x[y_result== 0, 1], s = 100, c = 'red', label =  'High Income Low Spending') 
plt.scatter(x[y_result== 1, 0], x[y_result== 1, 1], s = 100, c = 'blue', label =  'Medium Income MediumSpending') 
plt.scatter(x[y_result== 2, 0], x[y_result== 2, 1], s = 100, c = 'purple',label = 'High Income HighSpending') 
plt.scatter(x[y_result== 3, 0], x[y_result== 3, 1], s = 100, c = 'cyan', label =  'Low Income Low Spending') 
plt.scatter(x[y_result== 4, 0], x[y_result== 4, 1], s = 100, c = 'magenta',  label = 'Low Income HighSpending') 
plt.scatter(kmeansObj.cluster_centers_[:, 0], kmeansObj.cluster_centers_[:, 1], s = 300, c = 'yellow', label ='Centroids')
plt.title('Clusters of customers')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend() 
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.2))  
plt.show()
