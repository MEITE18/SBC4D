# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset= pd.read_csv("D:\TP DEH ABOUBACAR\STAGE_SEJEN\MACHINE LEARNING\Mobile_Price.csv")
print(dataset)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# 5              1859     0          0.5         1   3       0          22
# 6              1821     0          1.7         0   4       1          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 9               509     1          0.6         1   2       1           9
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# ...

# %%
x=dataset.iloc[:, :-1].values #Prends toutes les colonnes sauf la derniere et affecte x toutes les colonnes sauf la derniere
y=dataset.iloc[:,-1].values # Affiche la derniere colonne et affecte à y la derniere colone
print(x)
print(y)
# Out:
# [[8.420e+02 0.000e+00 2.200e+00 ... 0.000e+00 0.000e+00 1.000e+00]
#  [1.021e+03 1.000e+00 5.000e-01 ... 1.000e+00 1.000e+00 0.000e+00]
#  [5.630e+02 1.000e+00 5.000e-01 ... 1.000e+00 1.000e+00 0.000e+00]
#  ...
#  [1.911e+03 0.000e+00 9.000e-01 ... 1.000e+00 1.000e+00 0.000e+00]
#  [1.512e+03 0.000e+00 9.000e-01 ... 1.000e+00 1.000e+00 1.000e+00]
#  [5.100e+02 1.000e+00 2.000e+00 ... 1.000e+00 1.000e+00 1.000e+00]]
# [1 2 2 ... 3 0 3]

# %%
dataset[48:-1]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 48              578     1          2.6         1   2       1          57
# 49              596     0          2.1         1   9       0          64
# 50             1547     1          3.0         1   2       1          14
# 51             1760     0          1.4         1   5       0          63
# 52             1654     1          1.5         1   0       1          43
# 53             1457     0          1.9         1   1       1          16
# 54             1073     1          0.5         1   0       0          51
# 55             1936     0          2.1         1  10       1          46
# 56              823     1          2.7         1  13       0          60
# 57              987     0          1.3         1   0       1          61
# 58             1757     0          0.5         0   8       0          49
# 59             1063     0          1.4         1   2       1          48
# ...

# %%
#Scinder le jeu de données d'apprentissage et données test
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

from sklearn.preprocessing import MinMaxScaler
sc_x =MinMaxScaler() #StandarScaler pour centrer reduit et pour l'autre c'est min_maxScaler
x_train=sc_x.fit_transform(x_train)
x_test =sc_x.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
classifierObj=LogisticRegression(random_state=0)
classifierObj.fit(x_train,y_train) #Base toi sur la R L pour essayer de comprendre les 0 & 1
#Prediction sur la donnée test
y_pred=classifierObj.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[ 94   1   0   0]
#  [ 18  49  25   0]
#  [  0  19  59  21]
#  [  0   0   2 112]]

# %%
2+3
# Out:
# 5

# %%
#Ajuster le classifier sur la donnée d’apprentissage. Créer un objet pour le classifier et appeler le classifierObj
from sklearn.neighbors import KNeighborsClassifier
classifierObj = KNeighborsClassifier(n_neighbors=3, p=2,metric='minkowski')
classifierObj.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
#Visualisation des données d'apprentissage
from matplotlib.colors import ListedColormap
x_set, y_set=x_train,y_train
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min()-1, stop=x_set[:,0].max()+1,step=0.01),np.arange(start=x_set[:,1].min()-1, stop=x_set[:,1].max()+1,step=0.01))
#start =x_set[:,0].min() donne les limites des axes , et on fait -+1 pour augmenter les marges
plt.contourf(x1,x2,classifierObj.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape), alpha=0.75, cmap=ListedColormap(('red','blue')))
#plt.contourf deninie la ligne de decision pour pouvoir faire la difference entre les differentes zone
plt.xlim(x1.min(),x1.max())
plt.xlim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j,0],x_set[y_set==j,1],c=ListedColormap(('red','blue'))(i),label=j)
plt.title('Logistic Regression (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-83775660cc6e> in <module>
#       4 x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min()-1, stop=x_set[:,0].max()+1,step=0.01),np.arange(start=x_set[:,1].min()-1, stop=x_set[:,1].max()+1,step=0.01))
#       5 #start =x_set[:,0].min() donne les limites des axes , et on fait -+1 pour augmenter les marges
# ----> 6 plt.contourf(x1,x2,classifierObj.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape), alpha=0.75, cmap=ListedColormap(('red','blue')))
#       7 #plt.contourf deninie la ligne de decision pour pouvoir faire la difference entre les differentes zone
#       8 plt.xlim(x1.min(),x1.max())
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     147         X = check_array(X, accept_sparse='csr')
#     148
# ...

# %%
from sklearn.metrics import confusion_matrix
#Prediction sur la donnée test
y_pred=classifierObj.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[49 30 10  6]
#  [38 31 20  3]
#  [24 35 29 11]
#  [10 28 38 38]]

# %%
[[52 32  8  3]
 [35 34 19  4]
 [12 36 37 14]
 [ 6 21 50 37]]
