# %%
import numpy as np
import pandas as pd

source = "HDR 2007-2008 Table 05.xlsx"

df = pd.read_excel(source)
df.head(12)
# Out:
#               Unnamed: 0                            Unnamed: 1  Unnamed: 2  \
# 0                    NaN  .. to lead a long and healthy life …         NaN
# 1   5 Demographic trends                                   NaN         NaN
# 2                    NaN                                   NaN         NaN
# 3                    NaN                                   NaN         NaN
# 4                    NaN                                   NaN         NaN
# 5                    NaN                                   NaN         NaN
# 6                    NaN                                   NaN         NaN
# 7                    NaN                                   NaN         NaN
# 8                    NaN                                   NaN         NaN
# 9                    NaN                                   NaN         NaN
# 10              HDI rank                                   NaN         NaN
# 11                   NaN                                   NaN         NaN
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                                 NaN        NaN        NaN
# 5                                                 NaN        NaN        NaN
# 6                                                 NaN        NaN        NaN
# 7                                                 NaN        NaN        NaN
# 8                                                 NaN        NaN        NaN
# 9                                                 NaN        NaN        NaN
# 10  Total population                              ...        NaN        NaN
# 11                                               1975        NaN       2005
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# 4         NaN        NaN        NaN
# 5         NaN        NaN        NaN
# 6         NaN        NaN        NaN
# 7         NaN        NaN        NaN
# 8         NaN        NaN        NaN
# 9         NaN        NaN        NaN
# 10        NaN        NaN        NaN
# 11        NaN      2015b        NaN
#
#                                            Unnamed: 9  ... Unnamed: 21  \
# 0                                                 NaN  ...         NaN
# 1                                                 NaN  ...         NaN
# 2                                                 NaN  ...         NaN
# 3                                                 NaN  ...         NaN
# 4                                                 NaN  ...         NaN
# 5                                                 NaN  ...         NaN
# 6                                                 NaN  ...         NaN
# 7                                                 NaN  ...         NaN
# 8                                                 NaN  ...         NaN
# 9                                                 NaN  ...         NaN
# 10  Annual population growth rate                 ...  ...         NaN
# 11                                          1975-2005  ...       2015b
#
#    Unnamed: 22                                 Unnamed: 23 Unnamed: 24  \
# 0          NaN                                         NaN         NaN
# 1          NaN                                         NaN         NaN
# 2          NaN                                         NaN         NaN
# 3          NaN                                         NaN         NaN
# 4          NaN                                         NaN         NaN
# 5          NaN                                         NaN         NaN
# 6          NaN                                         NaN         NaN
# 7          NaN                                         NaN         NaN
# 8          NaN                                         NaN         NaN
# 9          NaN                                         NaN         NaN
# 10         NaN  Population aged 65 and older\n(% of total)         NaN
# 11         NaN                                        2005         NaN
#
#     Unnamed: 25  Unnamed: 26                               Unnamed: 27  \
# 0           NaN          NaN                                       NaN
# 1           NaN          NaN                                       NaN
# 2           NaN          NaN                                       NaN
# 3           NaN          NaN                                       NaN
# 4           NaN          NaN                                       NaN
# 5           NaN          NaN                                       NaN
# 6           NaN          NaN                                       NaN
# 7           NaN          NaN                                       NaN
# 8           NaN          NaN                                       NaN
# 9           NaN          NaN                                       NaN
# 10          NaN          NaN  Total fertility rate\n(births per woman)
# 11        2015b          NaN                                  1970-75c
#
#    Unnamed: 28  Unnamed: 29 Unnamed: 30
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
# 3          NaN          NaN         NaN
# 4          NaN          NaN         NaN
# 5          NaN          NaN         NaN
# 6          NaN          NaN         NaN
# 7          NaN          NaN         NaN
# 8          NaN          NaN         NaN
# 9          NaN          NaN         NaN
# 10         NaN          NaN         NaN
# 11         NaN     2000-05c         NaN
#
# [12 rows x 31 columns]

# %%
# Repositionner la ligne d'en-tête
df = pd.read_excel(source, header=10)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0                HDI rank        NaN         NaN
# 1                     NaN        NaN         NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN         NaN
# 3                       1    Iceland         NaN
# 4                       2     Norway         NaN
# 5                       3  Australia         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Total population                              ...        NaN        NaN
# 1                                               1975        NaN       2005
# 2                                                NaN        NaN        NaN
# 3                                                0.2        NaN        0.3
# 4                                                4.0        NaN        4.6
# 5                                               13.6        NaN       20.3
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN
# 1        NaN      2015b        NaN
# 2        NaN        NaN        NaN
# 3        NaN        0.3        NaN
# 4        NaN        4.9        NaN
# 5        NaN       22.4        NaN
#
#                                           Unnamed: 9  ... Unnamed: 21  \
# 0  Annual population growth rate                 ...  ...         NaN
# 1                                          1975-2005  ...       2015b
# 2                                                NaN  ...         NaN
# 3                                                1.0  ...        20.0
# 4                                                0.5  ...        17.7
# 5                                                1.3  ...        17.9
#
#   Unnamed: 22                                 Unnamed: 23 Unnamed: 24  \
# 0         NaN  Population aged 65 and older\n(% of total)         NaN
# 1         NaN                                        2005         NaN
# 2         NaN                                         NaN         NaN
# 3         NaN                                        11.7         NaN
# 4         NaN                                        14.7         NaN
# 5         NaN                                        13.1         NaN
#
#    Unnamed: 25  Unnamed: 26                               Unnamed: 27  \
# 0          NaN          NaN  Total fertility rate\n(births per woman)
# 1        2015b          NaN                                  1970-75c
# 2          NaN          NaN                                       NaN
# 3         14.2          NaN                                       2.8
# 4         17.0          NaN                                       2.2
# 5         16.1          NaN                                       2.5
#
#   Unnamed: 28  Unnamed: 29 Unnamed: 30
# 0         NaN          NaN         NaN
# 1         NaN     2000-05c         NaN
# 2         NaN          NaN         NaN
# 3         NaN          2.0         NaN
# 4         NaN          1.8         NaN
# 5         NaN          1.8         NaN
#
# [6 rows x 31 columns]

# %%
# https://stackoverflow.com/a/51794989
# Supprimez d'abord toutes les colonnes (axe=1) sans valeurs
df = df.dropna(how="all", axis=1)
# Supprimer toutes les lignes (axe=0) sans valeurs
df = df.dropna(how="all", axis=0).reset_index(drop=True)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1  \
# 0                HDI rank        NaN
# 1                     NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN
# 3                       1    Iceland
# 4                       2     Norway
# 5                       3  Australia
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Total population                              ...        NaN        NaN
# 1                                               1975        NaN       2005
# 2                                                NaN        NaN        NaN
# 3                                                0.2        NaN        0.3
# 4                                                4.0        NaN        4.6
# 5                                               13.6        NaN       20.3
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN
# 1        NaN      2015b        NaN
# 2        NaN        NaN        NaN
# 3        NaN        0.3        NaN
# 4        NaN        4.9        NaN
# 5        NaN       22.4        NaN
#
#                                           Unnamed: 9 Unnamed: 10  ...  \
# 0  Annual population growth rate                 ...         NaN  ...
# 1                                          1975-2005         NaN  ...
# 2                                                NaN         NaN  ...
# 3                                                1.0         NaN  ...
# 4                                                0.5         NaN  ...
# 5                                                1.3         NaN  ...
#
#   Unnamed: 12                                        Unnamed: 13 Unnamed: 15  \
# 0         NaN  Urban populationa                             ...         NaN
# 1         NaN                                               1975      2005.0
# 2         NaN                                                NaN         NaN
# 3         NaN                                               86.7        92.8
# 4         NaN                                               68.2        77.4
# 5         NaN                                               85.9        88.2
#
#    Unnamed: 17                                        Unnamed: 19 Unnamed: 21  \
# 0          NaN  Population under age 15                  \n   ...         NaN
# 1        2015b                                               2005       2015b
# 2          NaN                                                NaN         NaN
# 3         93.6                                               22.1        20.0
# 4         78.6                                               19.6        17.7
# 5         89.9                                               19.5        17.9
#
#                                   Unnamed: 23 Unnamed: 25  \
# 0  Population aged 65 and older\n(% of total)         NaN
# 1                                        2005       2015b
# 2                                         NaN         NaN
# 3                                        11.7        14.2
# 4                                        14.7        17.0
# 5                                        13.1        16.1
#
#                                 Unnamed: 27 Unnamed: 29
# 0  Total fertility rate\n(births per woman)         NaN
# 1                                  1970-75c    2000-05c
# 2                                       NaN         NaN
# 3                                       2.8         2.0
# 4                                       2.2         1.8
# 5                                       2.5         1.8
#
# [6 rows x 21 columns]

# %%
columns = []
for c in df.columns:
    # Pour chaque colonne, obtenir les valeurs des 5 premières lignes
    # puis conservez toutes les chaînes (c'est-à-dire excluez-les si elles sont nulles) et ajoutez-les en colonne
    columns.append([str(v) for v in df[c][:2] if pd.notnull(v)])
columns
# Out:
# [['HDI rank'],
#  [],
#  ['Total population                                                                           (millions)',
#   '1975'],
#  [],
#  ['2005'],
#  [],
#  ['2015b'],
#  [],
#  ['Annual population growth rate                                                                                         (%)',
#   '1975-2005'],
#  [],
#  ['2005-15b'],
#  [],
#  ['Urban populationa                                   (% of total)', '1975'],
#  ['2005.0'],
#  ['2015b'],
#  ['Population under age 15                  \n   (% of total)', '2005'],
#  ['2015b'],
#  ['Population aged 65 and older\n(% of total)', '2005'],
#  ['2015b'],
#  ['Total fertility rate\n(births per woman)', '1970-75c'],
#  ['2000-05c']]

# %%
ncolumns = [
    "HDI rank",
    "Country",
    "Total population (millions) 1975",
    "a",
    "Total population (millions)2005",
    "b",
    "Total population (millions)2015b",
    "c",
    "Annual population growth rate  (%) 1975-2005",
    "d",
    "Annual population growth rate  (%) 2005-15b",
    "e",
    "Urban populationa (% of total) 1975",
    "Urban populationa (% of total) 2005",
    "Urban populationa (% of total) 2015b",
    "Population under age 15 (% of total) 2005",   
    "Population under age 15 (% of total)2015b",
    "Population aged 65 and older(% of total) 2005",   
    "Population aged 65 and older(% of total) 2015b",
    "Total fertility rate (births per woman)1970-75c",
    "Total fertility rate (births per woman)2000-05c"
]

# %%
# Réinitialiser les colonnes des cadres de données
df.columns = ncolumns
df.head()
# Out:
#                  HDI rank  Country  \
# 0                HDI rank      NaN
# 1                     NaN      NaN
# 2  HIGH HUMAN DEVELOPMENT      NaN
# 3                       1  Iceland
# 4                       2   Norway
#
#                     Total population (millions) 1975    a  \
# 0  Total population                              ...  NaN
# 1                                               1975  NaN
# 2                                                NaN  NaN
# 3                                                0.2  NaN
# 4                                                4.0  NaN
#
#   Total population (millions)2005    b Total population (millions)2015b    c  \
# 0                             NaN  NaN                              NaN  NaN
# 1                            2005  NaN                            2015b  NaN
# 2                             NaN  NaN                              NaN  NaN
# 3                             0.3  NaN                              0.3  NaN
# 4                             4.6  NaN                              4.9  NaN
#
#         Annual population growth rate  (%) 1975-2005    d  ...    e  \
# 0  Annual population growth rate                 ...  NaN  ...  NaN
# 1                                          1975-2005  NaN  ...  NaN
# 2                                                NaN  NaN  ...  NaN
# 3                                                1.0  NaN  ...  NaN
# 4                                                0.5  NaN  ...  NaN
#
#                  Urban populationa (% of total) 1975  \
# 0  Urban populationa                             ...
# 1                                               1975
# 2                                                NaN
# 3                                               86.7
# 4                                               68.2
#
#   Urban populationa (% of total) 2005  Urban populationa (% of total) 2015b  \
# 0                                 NaN                                   NaN
# 1                              2005.0                                 2015b
# 2                                 NaN                                   NaN
# 3                                92.8                                  93.6
# 4                                77.4                                  78.6
#
#            Population under age 15 (% of total) 2005  \
# 0  Population under age 15                  \n   ...
# 1                                               2005
# 2                                                NaN
# 3                                               22.1
# 4                                               19.6
#
#   Population under age 15 (% of total)2015b  \
# 0                                       NaN
# 1                                     2015b
# 2                                       NaN
# 3                                      20.0
# 4                                      17.7
#
#   Population aged 65 and older(% of total) 2005  \
# 0    Population aged 65 and older\n(% of total)
# 1                                          2005
# 2                                           NaN
# 3                                          11.7
# 4                                          14.7
#
#   Population aged 65 and older(% of total) 2015b  \
# 0                                            NaN
# 1                                          2015b
# 2                                            NaN
# 3                                           14.2
# 4                                           17.0
#
#   Total fertility rate (births per woman)1970-75c  \
# 0        Total fertility rate\n(births per woman)
# 1                                        1970-75c
# 2                                             NaN
# 3                                             2.8
# 4                                             2.2
#
#   Total fertility rate (births per woman)2000-05c
# 0                                             NaN
# 1                                        2000-05c
# 2                                             NaN
# 3                                             2.0
# 4                                             1.8
#
# [5 rows x 21 columns]

# %%
len(df.columns)-len(ncolumns)
# Out:
# 0

# %%
df.columns
# Out:
# Index(['HDI rank', 'Country', 'Total population (millions) 1975', 'a',
#        'Total population (millions)2005', 'b',
#        'Total population (millions)2015b', 'c',
#        'Annual population growth rate  (%) 1975-2005', 'd',
#        'Annual population growth rate  (%) 2005-15b', 'e',
#        'Urban populationa (% of total) 1975',
#        'Urban populationa (% of total) 2005',
#        'Urban populationa (% of total) 2015b',
#        'Population under age 15 (% of total) 2005',
#        'Population under age 15 (% of total)2015b',
#        'Population aged 65 and older(% of total) 2005',
#        'Population aged 65 and older(% of total) 2015b',
#        'Total fertility rate (births per woman)1970-75c',
#        'Total fertility rate (births per woman)2000-05c'],
#       dtype='object')

# %%
# Supprimer les lignes qui contenaient les informations dont nous n'avons plus besoin
# et réinitialiser l'index
# np.arange(5) crée un tableau = [0, 1, 2, 3, 4, 5]
df = df.drop(np.arange(2), axis=0).reset_index(drop=True)
df.head()
# Out:
#                  HDI rank    Country Total population (millions) 1975    a  \
# 0  HIGH HUMAN DEVELOPMENT        NaN                              NaN  NaN
# 1                       1    Iceland                              0.2  NaN
# 2                       2     Norway                              4.0  NaN
# 3                       3  Australia                             13.6  NaN
# 4                       4     Canada                             23.1  NaN
#
#   Total population (millions)2005    b Total population (millions)2015b    c  \
# 0                             NaN  NaN                              NaN  NaN
# 1                             0.3  NaN                              0.3  NaN
# 2                             4.6  NaN                              4.9  NaN
# 3                            20.3  NaN                             22.4  NaN
# 4                            32.3  NaN                             35.2  NaN
#
#   Annual population growth rate  (%) 1975-2005    d  ...    e  \
# 0                                          NaN  NaN  ...  NaN
# 1                                          1.0  NaN  ...  NaN
# 2                                          0.5  NaN  ...  NaN
# 3                                          1.3  NaN  ...  NaN
# 4                                          1.1  NaN  ...  NaN
#
#   Urban populationa (% of total) 1975 Urban populationa (% of total) 2005  \
# 0                                 NaN                                 NaN
# 1                                86.7                                92.8
# 2                                68.2                                77.4
# 3                                85.9                                88.2
# 4                                75.6                                80.1
#
#    Urban populationa (% of total) 2015b  \
# 0                                   NaN
# 1                                  93.6
# 2                                  78.6
# 3                                  89.9
# 4                                  81.4
#
#   Population under age 15 (% of total) 2005  \
# 0                                       NaN
# 1                                      22.1
# 2                                      19.6
# 3                                      19.5
# 4                                      17.6
#
#   Population under age 15 (% of total)2015b  \
# 0                                       NaN
# 1                                      20.0
# 2                                      17.7
# 3                                      17.9
# 4                                      15.6
#
#   Population aged 65 and older(% of total) 2005  \
# 0                                           NaN
# 1                                          11.7
# 2                                          14.7
# 3                                          13.1
# 4                                          13.1
#
#   Population aged 65 and older(% of total) 2015b  \
# 0                                            NaN
# 1                                           14.2
# 2                                           17.0
# 3                                           16.1
# 4                                           16.1
#
#   Total fertility rate (births per woman)1970-75c  \
# 0                                             NaN
# 1                                             2.8
# 2                                             2.2
# 3                                             2.5
# 4                                             2.0
#
#   Total fertility rate (births per woman)2000-05c
# 0                                             NaN
# 1                                             2.0
# 2                                             1.8
# 3                                             1.8
# 4                                             1.5
#
# [5 rows x 21 columns]

# %%
df.tail(30)
# Out:
#                                               HDI rank  \
# 171                                                169
# 172                                                170
# 173                                                171
# 174                                                172
# 175                                                173
# 176                                                174
# 177                                                175
# 178                                                176
# 179                                                177
# 180                               Developing countries
# 181                          Least developed countries
# 182                                        Arab States
# 183                          East Asia and the Pacific
# 184                    Latin America and the Caribbean
# 185                                         South Asia
# 186                                 Sub-Saharan Africa
# 187             Central and Eastern Europe and the CIS
# 188                                               OECD
# 189                                   High-income OECD
# 190                                                NaN
# 191                             High human development
# 192                           Medium human development
# 193                              Low human development
# 194                                        High income
# 195                                      Middle income
# 196                                         Low income
# 197                                              World
# 198                                              NOTES
# 199  a. Because data are based on national definiti...
# 200  SOURCES\nColumns 1–3 and 9–14: UN 2007e.\nColu...
#
#                       Country Total population (millions) 1975    a  \
# 171                  Ethiopia                             34.2  NaN
# 172                      Chad                              4.2  NaN
# 173  Central African Republic                              2.1  NaN
# 174                Mozambique                             10.6  NaN
# 175                      Mali                              5.4  NaN
# 176                     Niger                              4.9  NaN
# 177             Guinea-Bissau                              0.7  NaN
# 178              Burkina Faso                              6.1  NaN
# 179              Sierra Leone                          2.94455  NaN
# 180                       NaN                          2,972.0    T
# 181                       NaN                            357.6    T
# 182                       NaN                            144.4    T
# 183                       NaN                          1,312.3    T
# 184                       NaN                            323.9    T
# 185                       NaN                            835.4    T
# 186                       NaN                            314.1    T
# 187                       NaN                            366.6    T
# 188                       NaN                            928.0    T
# 189                       NaN                            766.8    T
# 190                       NaN                              NaN  NaN
# 191                       NaN                          1,280.6    T
# 192                       NaN                          2,514.9    T
# 193                       NaN                            218.5    T
# 194                       NaN                            793.3    T
# 195                       NaN                          2,054.2    T
# 196                       NaN                          1,218.0    T
# 197                       NaN                          4,076.1   Te
# 198                       NaN                              NaN  NaN
# 199                       NaN                              NaN  NaN
# 200                       NaN                              NaN  NaN
#
#     Total population (millions)2005    b Total population (millions)2015b  \
# 171                            79.0  NaN                            101.0
# 172                            10.1  NaN                             13.4
# 173                             4.2  NaN                              5.0
# 174                            20.5  NaN                             24.7
# 175                            11.6  NaN                             15.7
# 176                            13.3  NaN                             18.8
# 177                             1.6  NaN                              2.2
# 178                            13.9  NaN                             18.5
# 179                             5.6  NaN                              6.9
# 180                         5,215.0    T                          5,956.6
# 181                           765.7    T                            965.2
# 182                           313.9    T                            380.4
# 183                         1,960.6    T                          2,111.2
# 184                           556.6    T                            626.5
# 185                         1,587.4    T                          1,842.2
# 186                           722.7    T                            913.2
# 187                           405.2    T                            398.6
# 188                         1,172.6    T                          1,237.3
# 189                           931.5    T                            976.6
# 190                             NaN  NaN                              NaN
# 191                         1,658.7    T                          1,751.1
# 192                         4,239.6    T                          4,759.8
# 193                           508.7    T                            653.0
# 194                           991.5    T                          1,047.2
# 195                         3,084.7    T                          3,339.7
# 196                         2,425.5    T                          2,894.7
# 197                         6,514.8   Te                          7,295.1
# 198                             NaN  NaN                              NaN
# 199                             NaN  NaN                              NaN
# 200                             NaN  NaN                              NaN
#
#        c Annual population growth rate  (%) 1975-2005    d  ...    e  \
# 171  NaN                                          2.8  NaN  ...  NaN
# 172  NaN                                          3.0  NaN  ...  NaN
# 173  NaN                                          2.4  NaN  ...  NaN
# 174  NaN                                          2.2  NaN  ...  NaN
# 175  NaN                                          2.5  NaN  ...  NaN
# 176  NaN                                          3.3  NaN  ...  NaN
# 177  NaN                                          3.0  NaN  ...  NaN
# 178  NaN                                          2.8  NaN  ...  NaN
# 179  NaN                                          2.1  NaN  ...  NaN
# 180    T                                          1.9  NaN  ...  NaN
# 181    T                                          2.5  NaN  ...  NaN
# 182    T                                          2.6  NaN  ...  NaN
# 183    T                                          1.3  NaN  ...  NaN
# 184    T                                          1.8  NaN  ...  NaN
# 185    T                                          2.1  NaN  ...  NaN
# 186    T                                          2.8  NaN  ...  NaN
# 187    T                                          0.3  NaN  ...  NaN
# 188    T                                          0.8  NaN  ...  NaN
# 189    T                                          0.6  NaN  ...  NaN
# 190  NaN                                          NaN  NaN  ...  NaN
# 191    T                                          0.9  NaN  ...  NaN
# 192    T                                          1.7  NaN  ...  NaN
# 193    T                                          2.8  NaN  ...  NaN
# 194    T                                          0.7  NaN  ...  NaN
# 195    T                                          1.4  NaN  ...  NaN
# 196    T                                          2.3  NaN  ...  NaN
# 197   Te                                          1.6  NaN  ...  NaN
# 198  NaN                                          NaN  NaN  ...  NaN
# 199  NaN                                          NaN  NaN  ...  NaN
# 200  NaN                                          NaN  NaN  ...  NaN
#
#     Urban populationa (% of total) 1975 Urban populationa (% of total) 2005  \
# 171                                 9.5                                16.0
# 172                                15.6                                25.3
# 173                                32.0                                38.0
# 174                                 8.7                                34.5
# 175                                16.2                                30.5
# 176                                11.4                                16.8
# 177                                16.0                                29.6
# 178                                 6.4                                18.3
# 179                                21.2                                40.7
# 180                                26.5                                42.7
# 181                                14.8                                26.7
# 182                                41.8                                55.1
# 183                                20.5                                42.8
# 184                                61.1                                77.3
# 185                                21.2                                30.2
# 186                                21.2                                34.9
# 187                                57.7                                63.2
# 188                                66.9                                75.6
# 189                                69.3                                77.0
# 190                                                                     NaN
# 191                                66.4                                76.8
# 192                                23.8                                39.3
# 193                                18.6                                33.2
# 194                                69.4                                77.6
# 195                                34.7                                53.9
# 196                                20.5                                30.0
# 197                                37.2                                48.6
# 198                                 NaN                                 NaN
# 199                                 NaN                                 NaN
# 200                                 NaN                                 NaN
#
#      Urban populationa (% of total) 2015b  \
# 171                                  19.1
# 172                                  30.5
# 173                                  40.4
# 174                                  42.4
# 175                                  36.5
# 176                                  19.3
# 177                                  31.1
# 178                                  22.8
# 179                                  48.2
# 180                                  47.9
# 181                                  31.6
# 182                                  58.8
# 183                                  51.1
# 184                                  80.6
# 185                                  33.8
# 186                                  39.6
# 187                                  63.9
# 188                                  78.2
# 189                                  79.4
# 190                                   NaN
# 191                                  79.4
# 192                                  44.9
# 193                                  38.6
# 194                                    80
# 195                                  60.3
# 196                                  34.2
# 197                                  52.8
# 198                                   NaN
# 199                                   NaN
# 200                                   NaN
#
#     Population under age 15 (% of total) 2005  \
# 171                                      44.5
# 172                                      46.2
# 173                                      42.7
# 174                                      44.2
# 175                                      47.7
# 176                                      48.0
# 177                                      47.4
# 178                                      46.2
# 179                                      42.8
# 180                                      30.9
# 181                                      41.5
# 182                                      35.2
# 183                                      23.8
# 184                                      29.8
# 185                                      33.6
# 186                                      43.6
# 187                                      18.1
# 188                                      19.4
# 189                                      17.6
# 190                                       NaN
# 191                                      20.2
# 192                                      29.3
# 193                                      44.9
# 194                                      18.1
# 195                                      25.1
# 196                                      36.6
# 197                                      28.3
# 198                                       NaN
# 199                                       NaN
# 200                                       NaN
#
#     Population under age 15 (% of total)2015b  \
# 171                                      41.0
# 172                                      45.2
# 173                                      39.9
# 174                                      43.2
# 175                                      46.4
# 176                                      47.3
# 177                                      47.9
# 178                                      44.2
# 179                                      42.8
# 180                                      28.0
# 181                                      39.3
# 182                                      32.1
# 183                                      20.6
# 184                                      26.3
# 185                                      29.5
# 186                                      41.7
# 187                                      17.4
# 188                                      17.8
# 189                                      16.5
# 190                                       NaN
# 191                                      18.8
# 192                                      26.0
# 193                                      43.0
# 194                                      17.0
# 195                                      22.5
# 196                                      33.3
# 197                                      26.0
# 198                                       NaN
# 199                                       NaN
# 200                                       NaN
#
#     Population aged 65 and older(% of total) 2005  \
# 171                                           2.9
# 172                                           3.0
# 173                                           3.9
# 174                                           3.2
# 175                                           3.6
# 176                                           3.1
# 177                                           3.0
# 178                                           3.1
# 179                                           3.3
# 180                                           5.5
# 181                                           3.3
# 182                                           3.9
# 183                                           7.1
# 184                                           6.3
# 185                                           4.7
# 186                                           3.1
# 187                                          12.8
# 188                                          13.8
# 189                                          15.3
# 190                                           NaN
# 191                                          12.7
# 192                                           5.8
# 193                                           2.9
# 194                                          14.8
# 195                                           7.3
# 196                                           4.2
# 197                                           7.3
# 198                                           NaN
# 199                                           NaN
# 200                                           NaN
#
#     Population aged 65 and older(% of total) 2015b  \
# 171                                            3.1
# 172                                            2.8
# 173                                            3.7
# 174                                            3.4
# 175                                            3.0
# 176                                            3.4
# 177                                            2.7
# 178                                            2.6
# 179                                            3.3
# 180                                            6.4
# 181                                            3.5
# 182                                            4.4
# 183                                            8.8
# 184                                            7.7
# 185                                            5.4
# 186                                            3.2
# 187                                           12.9
# 188                                           16.1
# 189                                           18.0
# 190                                            NaN
# 191                                           14.5
# 192                                            6.8
# 193                                            3.0
# 194                                           17.3
# 195                                            8.6
# 196                                            4.7
# 197                                            8.3
# 198                                            NaN
# 199                                            NaN
# 200                                            NaN
#
#     Total fertility rate (births per woman)1970-75c  \
# 171                                             6.8
# 172                                             6.6
# 173                                             5.7
# 174                                             6.6
# 175                                             7.6
# 176                                             8.1
# 177                                             7.1
# 178                                             7.8
# 179                                             6.5
# 180                                             5.4
# 181                                             6.6
# 182                                             6.7
# 183                                             5.0
# 184                                             5.0
# 185                                             5.5
# 186                                             6.8
# 187                                             2.5
# 188                                             2.6
# 189                                             2.2
# 190                                             NaN
# 191                                             2.7
# 192                                             5.3
# 193                                             6.9
# 194                                             2.3
# 195                                             4.6
# 196                                             5.9
# 197                                             4.5
# 198                                             NaN
# 199                                             NaN
# 200                                             NaN
#
#     Total fertility rate (births per woman)2000-05c
# 171                                             5.8
# 172                                             6.5
# 173                                             5.0
# 174                                             5.5
# 175                                             6.7
# 176                                             7.4
# 177                                             7.1
# 178                                             6.4
# 179                                             6.5
# 180                                             2.9
# 181                                             4.9
# 182                                             3.6
# 183                                             1.9
# 184                                             2.5
# 185                                             3.2
# 186                                             5.5
# 187                                             1.5
# 188                                             1.7
# 189                                             1.7
# 190                                             NaN
# 191                                             1.8
# 192                                             2.6
# 193                                             6.0
# 194                                             1.7
# 195                                             2.1
# 196                                             3.8
# 197                                             2.6
# 198                                             NaN
# 199                                             NaN
# 200                                             NaN
#
# [30 rows x 21 columns]

# %%
# Déposer les lignes du bas des données que nous voulons conserver, jusqu'à la fin (défini comme len(df))
df = df.drop(np.arange(180,len(df)), axis=0).reset_index(drop=True)
df.tail()
# Out:
#     HDI rank        Country Total population (millions) 1975    a  \
# 175      173           Mali                              5.4  NaN
# 176      174          Niger                              4.9  NaN
# 177      175  Guinea-Bissau                              0.7  NaN
# 178      176   Burkina Faso                              6.1  NaN
# 179      177   Sierra Leone                          2.94455  NaN
#
#     Total population (millions)2005    b Total population (millions)2015b  \
# 175                            11.6  NaN                             15.7
# 176                            13.3  NaN                             18.8
# 177                             1.6  NaN                              2.2
# 178                            13.9  NaN                             18.5
# 179                             5.6  NaN                              6.9
#
#        c Annual population growth rate  (%) 1975-2005    d  ...    e  \
# 175  NaN                                          2.5  NaN  ...  NaN
# 176  NaN                                          3.3  NaN  ...  NaN
# 177  NaN                                          3.0  NaN  ...  NaN
# 178  NaN                                          2.8  NaN  ...  NaN
# 179  NaN                                          2.1  NaN  ...  NaN
#
#     Urban populationa (% of total) 1975 Urban populationa (% of total) 2005  \
# 175                                16.2                                30.5
# 176                                11.4                                16.8
# 177                                16.0                                29.6
# 178                                 6.4                                18.3
# 179                                21.2                                40.7
#
#      Urban populationa (% of total) 2015b  \
# 175                                  36.5
# 176                                  19.3
# 177                                  31.1
# 178                                  22.8
# 179                                  48.2
#
#     Population under age 15 (% of total) 2005  \
# 175                                      47.7
# 176                                      48.0
# 177                                      47.4
# 178                                      46.2
# 179                                      42.8
#
#     Population under age 15 (% of total)2015b  \
# 175                                      46.4
# 176                                      47.3
# 177                                      47.9
# 178                                      44.2
# 179                                      42.8
#
#     Population aged 65 and older(% of total) 2005  \
# 175                                           3.6
# 176                                           3.1
# 177                                           3.0
# 178                                           3.1
# 179                                           3.3
#
#     Population aged 65 and older(% of total) 2015b  \
# 175                                            3.0
# 176                                            3.4
# 177                                            2.7
# 178                                            2.6
# 179                                            3.3
#
#     Total fertility rate (births per woman)1970-75c  \
# 175                                             7.6
# 176                                             8.1
# 177                                             7.1
# 178                                             7.8
# 179                                             6.5
#
#     Total fertility rate (births per woman)2000-05c
# 175                                             6.7
# 176                                             7.4
# 177                                             7.1
# 178                                             6.4
# 179                                             6.5
#
# [5 rows x 21 columns]

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
# Se débarrasser des rangées avec les catégories HDI
# https://stackoverflow.com/a/27360130 & https://stackoverflow.com/a/12098586
df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)

# %%
# Référence pour np.where https://docs.scipy.org/doc/numpy/reference/generated/numpy.where.html
# Pensez que cela ressemble à une déclaration du type "if" : where(test est vrai, vrai-quelque chose, faux-quelque chose)
# ceci peut aussi être imbriqué : where(test is true, true-thing, where(new-test is true, true-thing, false-thing))
df.loc[:, "HDI category"] = np.where(df["HDI rank"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] < 71,
                                              "HIGH HUMAN DEVELOPMENT",
                                              "MEDIUM HUMAN DEVELOPMENT"
                                              
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)
df.head()
# Out:
#   HDI rank    Country Total population (millions) 1975    a  \
# 0        1    Iceland                              0.2  NaN
# 1        2     Norway                              4.0  NaN
# 2        3  Australia                             13.6  NaN
# 3        4     Canada                             23.1  NaN
# 4        5    Ireland                              3.2  NaN
#
#   Total population (millions)2005    b Total population (millions)2015b    c  \
# 0                             0.3  NaN                              0.3  NaN
# 1                             4.6  NaN                              4.9  NaN
# 2                            20.3  NaN                             22.4  NaN
# 3                            32.3  NaN                             35.2  NaN
# 4                             4.1  NaN                              4.8  NaN
#
#   Annual population growth rate  (%) 1975-2005    d  ...  \
# 0                                          1.0  NaN  ...
# 1                                          0.5  NaN  ...
# 2                                          1.3  NaN  ...
# 3                                          1.1  NaN  ...
# 4                                          0.9  NaN  ...
#
#   Urban populationa (% of total) 1975 Urban populationa (% of total) 2005  \
# 0                                86.7                                92.8
# 1                                68.2                                77.4
# 2                                85.9                                88.2
# 3                                75.6                                80.1
# 4                                53.6                                60.5
#
#   Urban populationa (% of total) 2015b  \
# 0                                 93.6
# 1                                 78.6
# 2                                 89.9
# 3                                 81.4
# 4                                 63.8
#
#    Population under age 15 (% of total) 2005  \
# 0                                       22.1
# 1                                       19.6
# 2                                       19.5
# 3                                       17.6
# 4                                       20.7
#
#   Population under age 15 (% of total)2015b  \
# 0                                      20.0
# 1                                      17.7
# 2                                      17.9
# 3                                      15.6
# 4                                      21.1
#
#   Population aged 65 and older(% of total) 2005  \
# 0                                          11.7
# 1                                          14.7
# 2                                          13.1
# 3                                          13.1
# 4                                          11.1
#
#   Population aged 65 and older(% of total) 2015b  \
# 0                                           14.2
# 1                                           17.0
# 2                                           16.1
# 3                                           16.1
# 4                                           12.4
#
#   Total fertility rate (births per woman)1970-75c  \
# 0                                             2.8
# 1                                             2.2
# 2                                             2.5
# 3                                             2.0
# 4                                             3.8
#
#   Total fertility rate (births per woman)2000-05c            HDI category
# 0                                             2.0  HIGH HUMAN DEVELOPMENT
# 1                                             1.8  HIGH HUMAN DEVELOPMENT
# 2                                             1.8  HIGH HUMAN DEVELOPMENT
# 3                                             1.5  HIGH HUMAN DEVELOPMENT
# 4                                             2.0  HIGH HUMAN DEVELOPMENT
#
# [5 rows x 22 columns]

# %%
#supprimer les colonnes vides
df = df.drop(["a","b","c","d","e"], axis=1) 
df.head()
# Out:
#   HDI rank    Country Total population (millions) 1975  \
# 0        1    Iceland                              0.2
# 1        2     Norway                              4.0
# 2        3  Australia                             13.6
# 3        4     Canada                             23.1
# 4        5    Ireland                              3.2
#
#   Total population (millions)2005 Total population (millions)2015b  \
# 0                             0.3                              0.3
# 1                             4.6                              4.9
# 2                            20.3                             22.4
# 3                            32.3                             35.2
# 4                             4.1                              4.8
#
#   Annual population growth rate  (%) 1975-2005  \
# 0                                          1.0
# 1                                          0.5
# 2                                          1.3
# 3                                          1.1
# 4                                          0.9
#
#   Annual population growth rate  (%) 2005-15b  \
# 0                                         0.8
# 1                                         0.6
# 2                                         1.0
# 3                                         0.9
# 4                                         1.5
#
#   Urban populationa (% of total) 1975  Urban populationa (% of total) 2005  \
# 0                                86.7                                 92.8
# 1                                68.2                                 77.4
# 2                                85.9                                 88.2
# 3                                75.6                                 80.1
# 4                                53.6                                 60.5
#
#   Urban populationa (% of total) 2015b  \
# 0                                 93.6
# 1                                 78.6
# 2                                 89.9
# 3                                 81.4
# 4                                 63.8
#
#   Population under age 15 (% of total) 2005  \
# 0                                      22.1
# 1                                      19.6
# 2                                      19.5
# 3                                      17.6
# 4                                      20.7
#
#   Population under age 15 (% of total)2015b  \
# 0                                      20.0
# 1                                      17.7
# 2                                      17.9
# 3                                      15.6
# 4                                      21.1
#
#   Population aged 65 and older(% of total) 2005  \
# 0                                          11.7
# 1                                          14.7
# 2                                          13.1
# 3                                          13.1
# 4                                          11.1
#
#   Population aged 65 and older(% of total) 2015b  \
# 0                                           14.2
# 1                                           17.0
# 2                                           16.1
# 3                                           16.1
# 4                                           12.4
#
#   Total fertility rate (births per woman)1970-75c  \
# 0                                             2.8
# 1                                             2.2
# 2                                             2.5
# 3                                             2.0
# 4                                             3.8
#
#   Total fertility rate (births per woman)2000-05c            HDI category
# 0                                             2.0  HIGH HUMAN DEVELOPMENT
# 1                                             1.8  HIGH HUMAN DEVELOPMENT
# 2                                             1.8  HIGH HUMAN DEVELOPMENT
# 3                                             1.5  HIGH HUMAN DEVELOPMENT
# 4                                             2.0  HIGH HUMAN DEVELOPMENT
